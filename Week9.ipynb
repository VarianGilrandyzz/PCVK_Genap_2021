# %% [markdown]
# <a href="https://colab.research.google.com/github/VarianGilrandyzz/PCVK_Genap_2021/blob/main/Week9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

img = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/J.png')

# %%
#3
kernel = np.ones((5,5), np.uint8)
dilation = cv.dilate(img, kernel, iterations = 1)

plt.subplot(121),plt.imshow(img),plt.title('Citra Awal')
plt.subplot(122),plt.imshow(dilation),plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f8d8e120d90>,
#  <matplotlib.image.AxesImage at 0x7f8d8db63d90>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
#4
kernel = np.ones((5,5), np.uint8)
erode = cv.erode(img, kernel, iterations = 1)

plt.subplot(121),plt.imshow(img),plt.title('Citra Awal')
plt.subplot(122),plt.imshow(erode),plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f8d8db70310>,
#  <matplotlib.image.AxesImage at 0x7f8d8dac3a50>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
#5
kernel = kernel = np.ones((5,5), np.uint8)
dilation = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(dilation), plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f8d8dac3f50>,
#  <matplotlib.image.AxesImage at 0x7f8d8da13d50>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
#6
kernel = kernel = np.ones((5,5), np.uint8)
erosi = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(erosi), plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f8d8d9a52d0>,
#  <matplotlib.image.AxesImage at 0x7f8d8d8e8fd0>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
#7
kernel = np.ones((7,7), np.uint8)
opening = cv.morphologyEx(img, cv.MORPH_OPEN, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(opening), plt.title('Citra Hasil Opening')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f8d8d8f4550>,
#  <matplotlib.image.AxesImage at 0x7f8d8d8452d0>,
#  Text(0.5, 1.0, 'Citra Hasil Opening'))

# %%
#8
kernel = np.ones((7,7), np.uint8)
closing = cv.morphologyEx(img, cv.MORPH_CLOSE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(closing), plt.title('Citra Hasil Closing')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f8d8d845810>,
#  <matplotlib.image.AxesImage at 0x7f8d8d790910>,
#  Text(0.5, 1.0, 'Citra Hasil Closing'))

# %%
#9 (SED = Cross 3)
kernel = cv.getStructuringElement(cv.MORPH_CROSS,(3,3))
dilation = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(dilation), plt.title('Citra Hasil Dilasi'  )
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f8d8d7003d0>,
#  <matplotlib.image.AxesImage at 0x7f8d8d65f410>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
#9 (SED = Cross 5)
kernel = cv.getStructuringElement(cv.MORPH_CROSS,(5,5))
dilation = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(dilation), plt.title('Citra Hasil Dilasi'  )
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f8d8d647750>,
#  <matplotlib.image.AxesImage at 0x7f8d8d5a8e90>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
#10 (SED = Circle 3)
kernel = cv.getStructuringElement(cv.MORPH_ELLIPSE,(3,3))
dilation = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(dilation), plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f8d8e0f34d0>,
#  <matplotlib.image.AxesImage at 0x7f8d8dad1350>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
#10 (SED = Circle 5)
kernel = cv.getStructuringElement(cv.MORPH_ELLIPSE,(5,5))
dilation = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(dilation), plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f8d8da32110>,
#  <matplotlib.image.AxesImage at 0x7f8d8d495f50>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
#11 (SED = Rectangle 3x5)
kernel = cv.getStructuringElement(cv.MORPH_RECT,(3,5))
erosi = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(erosi), plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f8d8d4224d0>,
#  <matplotlib.image.AxesImage at 0x7f8d8d371190>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
#11 (SED = Rectangle 5x7)
kernel = cv.getStructuringElement(cv.MORPH_RECT,(5,7))
erosi = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(erosi), plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f8d8d3716d0>,
#  <matplotlib.image.AxesImage at 0x7f8d8d2c13d0>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
#12 (SED = Line Vertikal 3)
kernel = np.ones((1,3), np.uint8)
erosi = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(erosi), plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f8d8d2c1910>,
#  <matplotlib.image.AxesImage at 0x7f8d8d218610>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
#12 (SED = Line Vertikal 5)
kernel = np.ones((1,5), np.uint8)
erosi = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(erosi), plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f8d8d218b50>,
#  <matplotlib.image.AxesImage at 0x7f8d8d0e7810>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))
