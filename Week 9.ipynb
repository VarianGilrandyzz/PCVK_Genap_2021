# %% [markdown]
# <a href="https://colab.research.google.com/github/VarianGilrandyzz/PCVK_Genap_2021/blob/main/Week%209.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# No 2

# %%
import cv2 
import numpy as np 
from matplotlib import pyplot as plt

img = cv2.imread('/content/drive/MyDrive/PCVK_MM/Images/J.png') 
plt.imshow(img)

# %% [markdown]
# No 3

# %%
kernel = np.ones((5,5), np.uint8)
dilation = cv2.dilate(img, kernel, iterations = 1)

plt.subplot(121),plt.imshow(img),plt.title('Citra Awal')
plt.subplot(122),plt.imshow(dilation),plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f7eb693a9d0>,
#  <matplotlib.image.AxesImage at 0x7f7eb68d6450>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %% [markdown]
# No 4

# %%
kernel = np.ones((5,5), np.uint8)
erosion = cv2.morphologyEx(img, cv2.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(erosion), plt.title('Citra Hasil Erosi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f7eb6974810>,
#  <matplotlib.image.AxesImage at 0x7f7eb67b9190>,
#  Text(0.5, 1.0, 'Citra Hasil Erosi'))

# %% [markdown]
#  No 5

# %%
kernel = np.ones((5,5), np.uint8)
dilation = cv2.morphologyEx(img, cv2.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(dilation), plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f7eb6738890>,
#  <matplotlib.image.AxesImage at 0x7f7eb670c290>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %% [markdown]
# No 6

# %%
kernel = np.ones((5,5), np.uint8)
erosion = cv2.morphologyEx(img, cv2.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(erosion), plt.title('Citra Hasil Erosi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f7eb668fa50>,
#  <matplotlib.image.AxesImage at 0x7f7eb665f350>,
#  Text(0.5, 1.0, 'Citra Hasil Erosi'))

# %% [markdown]
# No 7

# %%
kernel = np.ones((7,7), np.uint8)
opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(opening), plt.title('Citra Hasil Opening')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f7eb65e1c10>,
#  <matplotlib.image.AxesImage at 0x7f7eb65af5d0>,
#  Text(0.5, 1.0, 'Citra Hasil Opening'))

# %% [markdown]
# No 8

# %%
element = cv2.getStructuringElement(cv2.MORPH_RECT,(7,7))
erosion_dst = cv2.erode(img, element)
opening_dst = cv2.dilate(erosion_dst, element)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(opening_dst), plt.title('Citra Hasil Opening')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f7eb6531f90>,
#  <matplotlib.image.AxesImage at 0x7f7eb6480950>,
#  Text(0.5, 1.0, 'Citra Hasil Opening'))
